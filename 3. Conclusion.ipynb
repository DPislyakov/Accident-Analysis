# %% [markdown]
# # Были рассмотрены основные модели прогнозирования времнных рядов, а затем он были применены на нашем наборе данных с объяснением полученных результатов в разрезе каждой модели.

# %% [markdown]
# # Сравним оценку точности моделей прогнозирования временных рядов

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при посуточном прогнозировании (РФ)

# %%
a.plot(x='DayRF' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Посуточное прогнозирование(РФ)')

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при понедельном прогнозировании (РФ)

# %%
a.plot(x='WeekRF' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Понедельное прогнозирование(РФ)')

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при помесячном прогнозировании (РФ)

# %%
a.plot(x='MonthRF' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Помесячное прогнозирование(РФ)')

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при посуточном прогнозировании (Москва)

# %%
a.plot(x='DayMs' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Посуточное прогнозирование(Москва)')

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при понедельном прогнозировании (Москва)

# %%
a.plot(x='WeekMs' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Понедельное прогнозирование(Москва)')

# %% [markdown]
# ### Средняя квадратичная ошибка (в количстве ДТП) при помесячном прогнозировании (Москва)

# %%
a.plot(x='MonthMs' ,y='RMSE' ,kind='bar',fontsize=17, figsize =(10,10),title='Помесячное прогнозирование(Москва)')

# %% [markdown]
# ## Заметим, что наиболее стабильную точность результатов показала модель Prophet, основанная на ряде Фурье.

# %% [markdown]
# ## Модель рекурентных нейронных сетей LSTM показывает лучшие результаты точности при понедельном прогнозировании числа ДТП

# %% [markdown]
# ## Интегрированная модель авторегрессии скользящего среднего Arima и модель с добавлением параметра сезонности Sarima не дали хорошей точности в сравнении с моделями Prophet и LSTM

# %% [markdown]
# ## Модель Arima и Sarima автоматического на наборе данных определяли лучшие параметры p, d и q, где p - число наблюдений отставания, включенных в модель, также называемое порядком отставания, d -  количество раз, когда исходные наблюдения различаются, также называется степенью различия (степень дифференциации ряда), q - размер окна скользящей средней, также называемый порядком скользящей средней.
