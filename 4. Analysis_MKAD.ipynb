# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from matplotlib import pyplot as plt
# Out:
# C:\Users\Dimasyan\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# ...

# %%
df = gpd.read_file('DTP_MKAD.shp',encoding = 'cp1251')#DTP_ENTRANCE.shp
df
# Out:
#      field_1        date      time      district       n_p dtp_v s_pch osv  \
# 0     292293  2015-09-23  23:30:00  Южное Тушино  г Москва     2     1   1
# 1     292303  2017-05-08  19:50:00  Южное Тушино  г Москва     2     0   2
# 2     292304  2017-05-03  09:10:00  Южное Тушино  г Москва     2     1   2
# 3     292305  2017-05-02  20:30:00  Южное Тушино  г Москва     2     1   1
# 4     292310  2015-06-11  21:50:00  Южное Тушино  г Москва     2     1   1
# ...      ...         ...       ...           ...       ...   ...   ...  ..
# 2284  445566  2017-08-14  04:25:00    Крылатское  г Москва     2     1   1
# 2285  445594  2017-12-18  04:40:00    Крылатское  г Москва     2     1   1
# 2286  445600  2018-03-24  12:15:00    Крылатское  г Москва     2     1   2
# 2287  445657  2015-02-16  08:30:00    Крылатское  г Москва     2     1   2
# 2288  445658  2015-02-15  21:00:00    Крылатское  г Москва     2     0   1
#
#      change_org woman_drv  ...  \
# 0             2         0  ...
# ...

# %%
base = df.plot(color='white', alpha=.8, edgecolor='black', figsize=(50,50))
df.plot(ax=base, color='white', edgecolor='red', zorder=-1)

# %%
mkad = df.pdd_narush.value_counts().to_frame()

# %%
mkad[0:50]
# Out:
#                                                     pdd_narush
# Нарушение скоростного режима                              1536
# Нарушение правил перестроения                              649
# Нарушение правил расположения ТС на проезжей части          64
# Нарушение правил проезда                                    12
# Несоблюдение условий, разрешающих движение тран...          12
# Нарушение требований знаков                                  8
# Выезд на полосу встречного движения                          4
# Эксплуатация ТС с неисправностями                            2
# Создание помех для водителя в управлении трансп...           1
# Выход на ходу                                                1

# %%
df.loc[df['pdd_narush'].str.contains("дистанц"), 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'].str.contains("скорост"), 'pdd_narush'] = 'Нарушение скоростного режима'

df.loc[df['pdd_narush'].str.contains("перестр"), 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'].str.contains("бок"), 'pdd_narush'] = 'Нарушение правил перестроения'

df.loc[df['pdd_narush'].str.contains("расположения"), 'pdd_narush'] = 'Нарушение правил расположения ТС на проезжей части'
df.loc[df['pdd_narush'].str.contains("останов"), 'pdd_narush'] = 'Нарушение правил расположения ТС на проезжей части'

df.loc[df['pdd_narush'].str.contains("линий"), 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'].str.contains("знак"), 'pdd_narush'] = 'Нарушение требований знаков'

df.loc[df['pdd_narush'].str.contains("очередности"), 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'].str.contains("проезд"), 'pdd_narush'] = 'Нарушение правил проезда'

df.loc[df['pdd_narush'].str.contains("Оставление"), 'pdd_narush'] = 'Выход на ходу'

df.loc[df['pdd_narush'].str.contains("Эксплуатация"), 'pdd_narush'] = 'Эксплуатация ТС с неисправностями'

# %% [markdown]
# # Построим диаграмму распределения типов нарушения ПДД

# %%
mkad.plot(kind='bar',fontsize=17, figsize =(20,5))

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-8755919b3bd4> in <module>()
#       1 #from plotly.graph_objs import Scatter, Figure, Layout
# ----> 2 import plotly
#       3 import plotly.graph_objs as go
#       4 import json
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'plotly'
