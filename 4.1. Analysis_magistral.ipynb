# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from matplotlib import pyplot as plt
# Out:
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\Users\Dimasyan\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
df = gpd.read_file('DTP_ENTRANCE.shp',encoding = 'cp1251')#DTP_ENTRANCE.shp
df
# Out:
#      field_1        date      time        district       n_p dtp_v s_pch osv  \
# 0     292293  2015-09-23  23:30:00    Южное Тушино  г Москва     2     1   1
# 1     292305  2017-05-02  20:30:00    Южное Тушино  г Москва     2     1   1
# 2     292373  2016-07-18  01:45:00    Южное Тушино  г Москва     2     1   1
# 3     292390  2017-01-11  13:45:00    Южное Тушино  г Москва     2     1   2
# 4     292451  2015-07-19  16:00:00    Южное Тушино  г Москва     2     1   2
# ...      ...         ...       ...             ...       ...   ...   ...  ..
# 3376  448559  2019-06-15  10:20:00       Мещанский  г Москва     2     1   2
# 3377  448568  2018-06-25  13:27:00       Мещанский  г Москва     0     1   2
# 3378  448571  2018-06-16  22:06:00       Мещанский  г Москва     2     1   1
# 3379  448572  2018-06-11  14:35:00       Мещанский  г Москва     0     1   2
# 3380  460054  2015-08-06  18:20:00  Красносельский  г Москва     2     1   2
#
#      change_org woman_drv  ...  \
# ...

# %%
base = df.plot(color='white', alpha=.8, edgecolor='black', figsize=(50,50))
df.plot(ax=base, color='white', edgecolor='red', zorder=-1)

# %%
df = df[['pdd_narush'
]].copy()
print('------- N A R U S H E N I E ----------------------')
print(df.pdd_narush.value_counts())
# Out:
# ------- N A R U S H E N I E ----------------------
# Неправильный выбор дистанции                                                                                                     1072
# Нарушение правил перестроения                                                                                                     499
# Нарушение требований сигналов светофора                                                                                           367
# Несоответствие скорости конкретным условиям движения                                                                              292
# Нарушение правил расположения ТС на проезжей части                                                                                186
#                                                                                                                                  ...
# ...

# %%
magistr = df.pdd_narush.value_counts().to_frame()

# %%
magistr[0:50]
# Out:
#                                          pdd_narush
# Нарушение скоростного режима                   1405
# Нарушение правил перестроения                   578
# Нарушение требований сигналов светофора         397
# Нарушение правил проезда                        385
# Нарушение с пешеходами                          236
# Расположение ТС на проезжей части               202
# Выезд на полосу встречного движения             117
# Нарушение требований знаков                      54
# Эксплуатация неисправного ТС                      4

# %%
#Нарушение скоростного режима
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Несоответствие скорости конкретным условиям движения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Превышение установленной скорости движения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Несоответствие скорости конкретным условиям движения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил обгона', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Несоответствие скорости конкретным условиям движения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Несоответствие скорости конкретным условиям движения::Неправильный выбор дистанции::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Неправильный выбор дистанции::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Несоответствие скорости конкретным условиям движения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Несоответствие скорости конкретным условиям движения::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции ::Неправильный выбор дистанции', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Нарушение правил пользования общественным транспортом', 'pdd_narush'] = 'Нарушение скоростного режима'
df.loc[df['pdd_narush'] == 'Неправильный выбор дистанции::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение скоростного режима'
#Нарушение правил перестроения
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Несоблюдение бокового интервала', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Несоблюдение бокового интервала::Несоблюдение бокового интервала', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Нарушение правил остановки и стоянки', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Несоблюдение бокового интервала::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Нарушение правил перестроения::Нарушение правил расположен', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил пользования общественным транспортом::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил остановки и стоянки::Нарушение правил перестроения', 'pdd_narush'] = 'Нарушение правил перестроения'
df.loc[df['pdd_narush'] == 'Нарушение правил перестроения::Непредоставление преимущества в движении ТС, имеющему нанесенные на наружные поверхности специа', 'pdd_narush'] = 'Нарушение правил перестроения'
#Нарушение требований сигналов светофора
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Нарушение требований сигналов светофора::Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора::Нарушение требований дорожных знаков', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора::Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Нарушение требований дорожных знаков::Нарушение требований сигналов светофора', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов светофора::Непредоставление преимущества в движении ТС, имеющему нанесенные на наружные поверхно', 'pdd_narush'] = 'Нарушение требований сигналов светофора'
#расположение ТС на проезжей части
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил остановки и стоянки', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Несоблюдение условий, разрешающих движение транспорта задним ходом', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил остановки и стоянки::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Несоблюдение очередности проезда', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Нарушение требований линий разметки::Нарушение требований дорожных знаков', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения::Нарушение правил расположения ТС на проезжей части', 'pdd_narush'] = 'Расположение ТС на проезжей части'
df.loc[df['pdd_narush'] == 'Нарушение правил расположения ТС на проезжей части::Разворот в местах, где разворот запрещён', 'pdd_narush'] = 'Расположение ТС на проезжей части'
# Нарушение правил проезда
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Непредоставление преимущества в движении ТС, имеющему нанесенные на наружные поверхности специальные цветографические схемы, н', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков::Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения с разворотом, поворотом налево или объездом препятствия::Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Нарушение требований дорожных знаков::Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Непредоставление преимущества в движении ТС, имеющему нанесенные на наружные поверхности спе', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда::Нарушение требований линий разметки', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков::Нарушение правил пользования общественным транспортом::Нарушение правил пользов', 'pdd_narush'] = 'Нарушение правил проезда'
df.loc[df['pdd_narush'] == 'Несоблюдение условий, разрешающих движение транспорта задним ходом', 'pdd_narush'] = 'Нарушение правил проезда'
#Эксплуатация неисправного ТС
df.loc[df['pdd_narush'] == 'Эксплуатация ТС с техническими неисправностями, при которых запрещается их эксплуатация', 'pdd_narush'] = 'Эксплуатация неисправного ТС'
df.loc[df['pdd_narush'] == 'Эксплуатация технически неисправного ТС (проставляется в случае ДТП по причине технеисправности)', 'pdd_narush'] = 'Эксплуатация неисправного ТС'
# Пешеход
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода::Пересечение велосипедистом проезжей части по пешеходному переходу', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Пересечение велосипедистом проезжей части по пешеходному переходу::Нарушение правил проезда пешеходного перехода', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Пересечение велосипедистом проезжей части по пешеходному переходу', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Несоблюдение очередности проезда перекрестков::Пересечение велосипедистом проезжей части по пешеходному переходу', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Пересечение велосипедистом проезжей части по пешеходному переходу::Несоблюдение очередности проезда', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода::Несоблюдение условий, разрешающих движение транспорта задним ходом', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода::Движение во встречном направлении по дороге с односторонним движением', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил проезда пешеходного перехода::Нарушение правил проезда пешеходного перехода', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил пользования общественным транспортом', 'pdd_narush'] = 'Нарушение с пешеходами'
df.loc[df['pdd_narush'] == 'Нарушение правил пользования общественным транспортом::Нарушение правил пользования общественным транспортом', 'pdd_narush'] = 'Нарушение с пешеходами'
#Выезд на полосу встречного движения
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения в местах, где это запрещено', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения с разворотом, поворотом налево или объездом препятствия', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Разворот в местах, где разворот запрещён', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Движение во встречном направлении по дороге с односторонним движением', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения в местах, где это запрещено::Выезд на полосу встречного движения с разворотом, поворотом н', 'pdd_narush'] = 'Выезд на полосу встречного движения'
df.loc[df['pdd_narush'] == 'Выезд на полосу встречного движения с разворотом, поворотом налево или объездом препятствия::Нарушение требований линий размет', 'pdd_narush'] = 'Выезд на полосу встречного движения'
#Нарушение требований знаков
df.loc[df['pdd_narush'] == 'Нарушение требований дорожных знаков', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований линий разметки', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований линий разметки::Нарушение требований дорожных знаков', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований сигналов регулировщика', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований дорожных знаков::Нарушение требований дорожных знаков', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований линий разметки::Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение требований знаков'
df.loc[df['pdd_narush'] == 'Нарушение требований дорожных знаков::Несоблюдение очередности проезда перекрестков', 'pdd_narush'] = 'Нарушение требований знаков'
#Убираем
df = df.drop(df[df['pdd_narush'] == 'Нарушение правил погрузки, выгрузки и крепления грузов'].index)
df = df.drop(df[df['pdd_narush'] == 'Оставление движущегося транспортного средства (выход или выпрыгивание на ходу и т.д.)'].index)
df = df.drop(df[df['pdd_narush'] == 'Нарушение правил буксировки::Нарушение правил пользования внешними световыми приборами'].index)

# %%
df.pdd_narush.describe()
# Out:
# count                             3379
# unique                               8
# top       Нарушение скоростного режима
# freq                              1405
# Name: pdd_narush, dtype: object

# %% [markdown]
# # Построим диаграмму распределения типов нарушения ПДД

# %%
magistr.plot(kind='bar',fontsize=17, figsize =(20,5))
